# %% [markdown]
# <a href="https://colab.research.google.com/github/davearch/ML-Emails/blob/master/end_of_year_emails.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
data = pd.read_csv('data_eoy.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 16 columns):
# date               27 non-null object
# theme              27 non-null int64
# day                27 non-null object
# time               27 non-null object
# delivered          27 non-null int64
# delivery_per       27 non-null float64
# opened             27 non-null int64
# open_per           27 non-null float64
# clicked            27 non-null int64
# click_per          27 non-null float64
# donations          27 non-null int64
# donation_per       27 non-null float64
# unsubscribes       27 non-null int64
# unsubscribe_per    27 non-null float64
# sentiment_score    27 non-null int64
# word_count         27 non-null int64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 3.5+ KB

# %%
data['date'] = pd.to_datetime(data['date'], format="%m/%d")

# %%
data['delivered'] = pd.to_numeric(data['delivered'])

# %%
 # !pip install -U pandas-profiling
# Out:
# ...
#      |████████████████████████████████| 153kB 5.2MB/s
# ...
#      |████████████████████████████████| 614kB 47.2MB/s
# ...
#      |████████████████████████████████| 235kB 51.1MB/s
# ...
#      |████████████████████████████████| 307kB 21.4MB/s
# ...
#      |████████████████████████████████| 215kB 41.2MB/s
# ...
#      |████████████████████████████████| 51kB 6.7MB/s
# ...
#      |████████████████████████████████| 61kB 8.9MB/s
# ...
#      |████████████████████████████████| 747kB 46.3MB/s
# ...
#   Created wheel for pandas-profiling: filename=pandas_profiling-2.4.0-py2.py3-none-any.whl size=195588 sha256=631aa19f2ea5d86fa411bddc1f5c5455490cb8466116e8ff542986d5936c36fa
#   Stored in directory: /root/.cache/pip/wheels/b2/4b/40/ff4633a59f4e7fbdfec19b8e10e353b54b5eef125c31afe51a
# ...
#   Created wheel for confuse: filename=confuse-1.0.0-cp36-none-any.whl size=17487 sha256=82b009a180da4dc6123a87e1df9715f37bb7813076c06f0049b95ad997f2dd0c
# ...

# %%
import pandas_profiling

profile = data.profile_report(title='EOY')
profile.to_file(output_file="eoy.html")

# %%
data
# Out:
#          date  theme    day  ... unsubscribe_per  sentiment_score  word_count
# 0  1900-11-22      1  Thurs  ...            0.23               19         334
# 1  1900-11-25      2    Sun  ...            0.16               -1         725
# 2  1900-12-02      3    Sun  ...            0.18                7         282
# 3  1900-12-09      4    Sun  ...            0.22               31         858
# 4  1900-12-16      5    Sun  ...            0.13              -18         457
# 5  1900-12-24      6    Mon  ...            0.10                3         367
# 6  1900-12-25      7    Tue  ...            0.12                4         536
# 7  1900-12-26     17    Wed  ...            0.17               -9         452
# 8  1900-12-27      8    Thu  ...            0.09              -40         504
# 9  1900-12-28      9    Fri  ...            0.18               -8         344
# 10 1900-12-29     10    Sat  ...            0.12              -40         547
# ...
